# %% [markdown]
# #DSCI 617 – Homework 01
# **Shahid Abdulaziz**

# %% [markdown]
# **Add a code cell that imports that math package as well as the SparkSession class. Also include the
# following import statement: from pyspark.mllib.random import RandomRDDs**

# %%
import math
from pyspark.sql import SparkSession
from pyspark.mllib.random import RandomRDDs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Add another code cell to create SparkSession and sparkContext objects named spark and sc.**

# %%
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Problem 1: Terminology
# Create a markdown containing a numbered list with answers to the following questions. You only need to
# provide the answers and are not required to retype the questions. Each question requires only a 1 – 3 word
# answer.

# %% [markdown]
# 1. Scala
# 2. SparkSession
# 3. SparkContext
# 4. Resilient Distributed Datasets
# 5. Partitions
# 6. Transformation
# 7. Action
# 8. Transformation
# 9. Action
# 10. Transformation
# 11. Action
# 12. Python list
# 13. Driver Node
# 14. Worker Node
# 15. Spark Managers
# 16. Spark Executors

# %% [markdown]
# 1. Use the following line of code to create an RDD containing 1.2 million elements randomly selected
# from the interval [0,1]: random_rdd = RandomRDDs.uniformRDD(sc, size=1200000,
# seed=1)
# 2. Use built-in RDD methods to calculate the sum, mean, standard deviation, minimum, and maximum
# of the values stored in random_rdd. Display the results in the format shown below, replacing the
# xxxx strings with the appropriate values. Add spacing to ensure that the numerical values are leftaligned.

# %%
random_rdd = RandomRDDs.uniformRDD(sc, size=1200000, seed=1)

print("Sum:     " + str(random_rdd.sum()))
print("Mean:    " + str(random_rdd.mean()))
print("Std Dev: " + str(random_rdd.stdev()))
print("Minimum: " + str(random_rdd.min()))
print("Maximum: " + str(random_rdd.max()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Sum:     599075.0656203285
# Mean:    0.49922922135026476
# Std Dev: 0.28869756091861193
# Minimum: 1.0351479373671424e-07
# Maximum: 0.9999991929309536
# </div>

# %% [markdown]
# 1. Use the getNumPartitions() RDD method to determine the number of partitions used for
# random_rdd.
# 2. Use glom() and map() along with the built-in Python function len() to create a list that contains
# the number of elements contained within each of the partitions of random_rdd. Try to complete this
# task with a single line of code by chaining together RDD transformations, followed by collect().
# 3. Print the results in the format shown below, replace the xxxx strings with the appropriate values

# %%
random_rdd.getNumPartitions() #getting number of partitions used
print("Number of Partitions: ", random_rdd.getNumPartitions())
print("Number of Partitions: \n",  random_rdd.glom().map(len).collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of Partitions:  4
# Number of Partitions:
#  [300000, 300000, 300000, 300000]
# </div>

# %% [markdown]
# ## Problem 3: Transformations
# In the first code cell in Problem 3, we will scale the values in our randomly generated RDD to be in the range 0 to
# 10 rather than the range 0 to 1.

# %% [markdown]
# Complete the following steps in a single code cell:
# 1. Use the map() transformation to multiply each element of random_rdd by 10, storing the results in
# a variable named scaled_rdd.
# 2. Calculate the sum, mean, standard deviation, minimum, and maximum of the values stored in
# scaled_rdd. Display the results using the same format as in the first cell of Problem 2.
# We will now transform the values in our scaled RDD by applying the natural logarithm to each value.
# Complete the following steps in a single code cell:

# %%
scaled_rdd = random_rdd.map(lambda x: x*10)
print("Sum:     " + str(scaled_rdd .sum()))
print("Mean:    " + str(scaled_rdd .mean()))
print("Std Dev: " + str(scaled_rdd .stdev()))
print("Minimum: " + str(scaled_rdd .min()))
print("Maximum: " + str(scaled_rdd .max()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Sum:     5990750.656203327
# Mean:    4.99229221350273
# Std Dev: 2.886975609186112
# Minimum: 1.0351479373671424e-06
# Maximum: 9.999991929309536
# </div>

# %% [markdown]
# 1. Use the map() transformation along with the function math.log() to take the natural logarithm of
# each element in scaled_rdd. Store the new RDD in a variable named log_rdd.
# 2. Calculate the sum, mean, standard deviation, minimum, and maximum of the values stored in
# log_rdd. Display the results using the same format as in the previous cell.

# %%
log_rdd =scaled_rdd.map(lambda x: math.log(x))
print("Sum:     " + str(log_rdd.sum()))
print("Mean:    " + str(log_rdd.mean()))
print("Std Dev: " + str(log_rdd.stdev()))
print("Minimum: " + str(log_rdd.min()))
print("Maximum: " + str(log_rdd.max()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Sum:     1559584.3948350847
# Mean:    1.2996536623625732
# Std Dev: 1.0035829379691585
# Minimum: -13.780966206806882
# Maximum: 2.3025842859246737
# </div>

# %% [markdown]
# ## Problem 4: Calculating SSE
# In this problem, we will read in and process a data file containing two decimal values in each line. The first value
# is intended to represent an observed value of some random variable, while the second value is intended to
# represent a prediction generated by some model. We will use these values to calculate the sum of squared
# errors score for the predictions.

# %% [markdown]
# Complete the following steps in a single code cell:
# 1. Read the contents of the data file into and RDD named pairs_raw.
# 2. Display the number of elements contained in the pairs_raw RDD

# %%
pairs_raw = sc.textFile('/FileStore/tables/pairs_data.txt')
print(pairs_raw.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">12743548
# </div>

# %% [markdown]
# Use a for loop and the take() method to display the first 5 elements of pairs_raw. Note that these
# elements are stored as strings.

# %%
for row in pairs_raw.take(5):
    print(row)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">12.3 12.1
# 9.1 8.7
# 9.3 9.9
# 8.5 8.5
# 11.2 10.8
# </div>

# %% [markdown]
# Write a function named process_line(). The function should accept a single parameter named
# row. This parameter is intended to take on string values of the type stored in pairs_raw. The
# function should split the string at the space character, coerce each of the two tokens into float
# values, and return a tuple containing these two float values.
# 2. Use the map() transformation to apply process_line() to pairs_raw storing the resulting RDD
# in pairs.
# 3. Use a for loop and the take() method to display the first 5 elements of pairs.

# %%
def process_line(row):
    obj = row.split(' ')
       
    return(float(obj[0]),float(obj[1]))




    
    
pairs = pairs_raw.map(process_line)


for row in pairs.take(5):
    print(row)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(12.3, 12.1)
# (9.1, 8.7)
# (9.3, 9.9)
# (8.5, 8.5)
# (11.2, 10.8)
# </div>

# %% [markdown]
# 1. Use map() with a lambda function to calculate the squared difference of each pair of values stored
# in pairs. Then call the sum() method of the resulting RDD, storing the result in a variable named
# SSE.
# 2. Print the value of SSE.

# %%
SSE = pairs.map(lambda x: (float(x[0]) - float(x[1]))**2     ).sum()
print("The SSE is: ", SSE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The SSE is:  4597380.190042952
# </div>

# %% [markdown]
# ## Problem 5: Calculating r-Squared
# We will continue the analysis started in Problem 4 by calculating the r-squared score for our predictions. The
# first step in this process in to calculate the mean of the observed values.

# %% [markdown]
# Complete the following steps in a single code cell:
# 1. Use the map() transformation along with a lambda function to select the first element of each tuple
# in the pairs RDD. Call the mean() method of the resulting RDD, storing the result in a variable
# named mean.
# 2. Print mean.
# Note that this calculation might take a couple of minutes to complete.

# %%
Mean = pairs.map(lambda x: x[0]).mean()
print(Mean)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10.00013136059118
# </div>

# %% [markdown]
# Complete the following steps in a single code cell:
# 1. Use the map() transformation along with a lambda function to calculate the square of the difference
# between each observed value in pairs and mean. Call the sum() method of the resulting RDD,
# storing the result in a variable named SST.
# 2. Print SST.

# %%
SST = pairs.map(lambda x:  float(x[1]) - Mean).sum()
print(SST)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1220.900001131684
# </div>

# %% [markdown]
# We will now calculate the r-squared score for the predictions. The formula for this value is given as follow: 𝑟
# 2 =
# 1 −
# 𝑆𝑆𝐸
# 𝑆𝑆𝑇
# Complete the following steps in a single code cell:
# 1. Use SSE and SST to calculate r-squared, storing the result in a variable named r2.
# 2. Print r2

# %%
r2 = 1 - (SSE/SST)

print(r2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-3764.5665376210345
# </div>

# %% [markdown]
# d ## Problem 6: NASA Server Logs
#  In this problem, we will explore one month of server logs for the NASA.gov website. These logs are from August
# 1995 and contain information about every request received by the server during that month. The path for the
# file within which these logs are stored is /FileStore/tables/NASA_server_logs_Aug_1995.txt.

# %% [markdown]
# Complete the following steps in a single code cell:
# 1. Read the contents of the data file into an RDD named nasa.
# 2. Display the number of elements contained in the nasa RDD

# %%
nasa = sc.textFile('/FileStore/tables/NASA_server_logs_Aug_1995.txt')
print(nasa.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1569888
# </div>

# %% [markdown]
# Use a for loop and the take() method to display the first 5 elements of nasa

# %%
for row in nasa.take(5):
    print(row)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">in24.inetnebr.com [01/Aug/1995:00:00:01] &#34;GET /shuttle/missions/sts-68/news/sts-68-mcc-05.txt&#34; 200 1839
# uplherc.upl.com [01/Aug/1995:00:00:07] &#34;GET /&#34; 304 0
# uplherc.upl.com [01/Aug/1995:00:00:08] &#34;GET /images/ksclogo-medium.gif&#34; 304 0
# uplherc.upl.com [01/Aug/1995:00:00:08] &#34;GET /images/MOSAIC-logosmall.gif&#34; 304 0
# uplherc.upl.com [01/Aug/1995:00:00:08] &#34;GET /images/USA-logosmall.gif&#34; 304 0
# </div>

# %% [markdown]
# 1. Use the lambda function shown below to map each line of the server log to a Boolean value
# indicating whether or not the line contains the string 'GET'. Call the sum() method of the resulting
# RDD to count the number of GET requests.
# lambda x : 'GET' in x
# 2. Modify the process used in step one to determine the number of POST requests and the number of
# HEAD requests.
# 3. Print the results in the format shown below.

# %%
print("Number of GET requests:   "+ str(nasa.map(lambda x : 'GET' in x).sum()))
print("Number of POST requests:  "+ str(nasa.map(lambda x : 'POST' in x).sum()))
print("Number of HEAD requests:  "+ str(nasa.map(lambda x : 'HEAD' in x).sum()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of GET requests:   1565812
# Number of POST requests:  111
# Number of HEAD requests:  3965
# </div>
